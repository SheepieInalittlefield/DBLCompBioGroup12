# %%
## import libraries
# %load_ext autoreload
# %autoreload 2
import utilities as util
import os
import reedsolo
import random
import time
import matplotlib.pyplot as plt

# %%
## set variables
path = os.path.relpath("C:\\Users\\20192903\\Documents\\GitHub\\DBLCompBioGroup12\\Data\\Research_Proposal_Group_12-1.pdf")
seed = 7
extra = 1.07
max_homopolymer = 3
DNA_filename = "DNA_strands.txt"

# %%
def Encode(file_path, seed, extra = 1.05, max_homopolymer = 3) -> list:
    """ Read and encode a file using the luby transform, returning a list of DNA sequences
    INPUT:
    file_path: path to the file to be encoded
    seed:  seed for the randomization of data
    extra: amount of extra droplets compared to data (default 5%, so 1.05)
    max_homopolymer: maximum length of homopolymer sequences allowed (default 3)
    OUTPUT:
    droplets: list of DNA sequences
    """
    # first read file
    data = util.OpenFile(file_path)
    # make bytearray from data
    data = bytearray(data)
    # randomize first
    data = util.RandomizeMessage(data, seed)
    # data needs to be converted to string for segmentation
    data = util.Bytearray2Binary(data)
    # add padding and segment
    data = util.Segment(data)
    # now the luby transform needs to be applied
    

    total_segments = len(data)
    distribution_size = total_segments 
    # first convert segments to bytearrays
    data_bytearray = [util.Binary2Bytearray(segment) for segment in data]
    
    # create a Pseudo random number generator 
    prng = random.Random()
    seeds_lfsr = util.LFSR() #starting an lfsr with a certain state and a polynomial for 32bits.
    nr_droplets_probablities = util.RobustSoliton(distribution_size, 0.001, 0.025)
    droplets = []
    droplets_required = int(extra*total_segments)
    while len(droplets) < droplets_required:
        # generate a seed for droplet making
        seed = next(seeds_lfsr)
        # create droplet
        current_drop = util.MakeDroplet(data_bytearray, seed, prng, nr_droplets_probablities)
        # convert drop to string and then DNA
        current_drop = util.Binary2DNA(util.Bytearray2Binary(current_drop))
        # check biochemical requirements and append to list of droplets if ok
        if util.CheckBiochemicalRequirements(current_drop, max_homopolymer):
            droplets.append(current_drop)
    
    ##make metadata-strands
    metastrand = util.CreateMetaStrand(total_segments)
    
    for x in range(3): # now 3 for adding it in 3 times
        droplets.append(metastrand)
    
    return droplets

# %%
encoded = Encode(path, seed, extra, max_homopolymer)

# %%
f = open(DNA_filename, "w")
for i in encoded:
    f.write(i + "\n")
f.close()

# %% [markdown]
# # DNA SYNTHESIS, STORAGE AND SEQUENCING

# %% [markdown]
# # DECODING

# %%
with open(DNA_filename, 'r') as f:
    dropletlist = [line.rstrip('\n') for line in f]

#total_segments = 15399 # moet geen variabele meer zijn

#check if all the droplets meet our requirements otherwise don't add them to the list of OKdroplets
metadata = []
OKdroplets = []
for strand in dropletlist:
    if util.CheckBiochemicalRequirements(strand):
        if util.CheckOligoLength(strand):
            if strand[:16] == "ACGTACGTACGTACGT":
                metadata.append(strand)
            else:
                OKdroplets.append(strand)

total_segments_list = [util.DecodeMetaStrand(metastrand) for metastrand in metadata]
total_segments = max(set(total_segments_list), key = total_segments_list.count)

simplified_droplets = []
rsc = reedsolo.RSCodec(2)
for strand in OKdroplets:
    binary_strand = util.DNA2Binary(strand)
    bytearray_strand = util.Binary2Bytearray(binary_strand)
#convert the list of strings to a bytearray 
    if rsc.check(bytearray_strand):
        droplet_seed = int(binary_strand[0:32], 2)
        segment_amount, segment_indices = util.RecoverSeed(droplet_seed, total_segments)
        payload = binary_strand[32:288]
        simplified_droplets.append((segment_indices, payload))
#if the strand is correct according to reed-solomon, 
#make a list including the segment indices of the droplet and #their combined XOR

# %%
output_data = {}
input_data = simplified_droplets
newsolves = 1
while newsolves > 0:
    input_data, output_data, newsolves = util.Decode(input_data, output_data)

# %%
if len(output_data)==total_segments:
    solution = ''.join([output_data[x] for x in range(15399)])
    solution = util.RemovePadding(solution)
    solution = util.RandomizeMessage(util.Binary2Bytearray(solution))
else:
    solution = 'solution could not be reached, use another more robust method ' + str(len(output_data))

# %%
with open("recovered.pdf", "wb") as file:
    file.write(solution)
# Out:
# bytearray(b'\xa4H\x90\x15%\x18\x1b\xbf\xf8\x93x;\x85T=]m\x94\x15P<\xbd\xc7\x98\x8fI\xb7D\xc2JGV\xec\xfd5\xf3sE\xd0\xca7wG\xb5\xcc\xf2\t\xcde}a\xc8f\xc2*7q\x96\xda%<y&\xba\xc6X\x9ay\x91\x18\x93\xe5\xec\xfb{\xac\xf9\xb6T\xf9\xdao7r\xfb\\\xd5\x1b\xd8A>\x9c\xa1b\xad\x80:\xe8\xd8\xb3\xf14\xa7\xd1\xc1\x9e\x7f\xf0\x11"\xff\x83\xb3*\x0c\x8a\x8f\xf2#\x0eD\xf5\xc9@\xcb\xd3\ng]Wp\x04\x0b\xca=\x03\xa5\xd1!\x82\xd2X\xf8\xb4v\x1f<\x7f\xc8c\xd9*\x06K\x15uA\x8a_\xbd\xc5\xee\x9e\xf9\x10r\xceT\x14\n\xed\xf3\x05\x84\xadn\xaa\xec\x91)\xd3/\x12\xb7d\x9bdW\xa1_\xb2a<\xc1\xaf*T\'\xc38b\xd0\xf5p\x17\xc6\xdbe\x12\xf7\xc4\xb6)\x85iC\x02-A4r\xc1\x1bt\x87\xcd\x13X"9\xa5\x15\xd3\xfb\x91\xdd,Iw\x05\x8d\xac\xbdN\xbd\xf3\x9d\xf6\x8bZ$\x88\x81=?\x03.\x1c\xe4\x19\xcd\x14Bq\xf3,\xa0\xa4\x03>\xdb\x0c\x91\x94}\x80\x104\xc3\xde\x89tS\x16~\x87{\xa6\x99\xda\x1cZ<\xc2\xf2\xdb\xafV\xb1\x8a\xdb\xbdmv8OH\x83V22\xf262<\x8f\xad\xdd\x9a^N\x03\xed\xa2\x0c\x88t\xbc\x1c\xdd\x8dO\xde)R\xa5\xc7\xd0\xe7\xc6f\xa1\xad\xc6\x05\x98&\x98$\xca\xa6`\xbdh\xcaWc\xcf\xd3\xa7\x17\x89\xf6\x97>\xea)\xecM`\x85\xbd\xbd\x1d,Q\'\xadc\x9b\xb2\x17\xa9\x05\xf9d\xb2c1\x1e3\x93\x98\xb6$\xfa\xe5\x86.x9L\xa0<\xa3\xcb\x92\rj\xc0\xbe\x02\xb2E\xa4\xe0\x08K:\xbcg\xcc3\xf5\x87\xf6l\xba<A\x05\x05\xe1jB\x06q\xa9y4L\x164A\x87\x90\x02B\n\x99\xed\xe6dm\xf3\xa4L8\x12\x17\xdc\xa86\xd7\xcc\xc1_\x0b\x03u\xe3~S\x02\x05\x0e\xfcr\x83\x1cn\x94\x81i\x99\x12/\xd7T\xfbm\xe7c\xd1"\xfc\xe7\xa4h\xce\x9fa\xe6\xca\x8f\xb0,\xdeX\x81bS\xdd\x15MH*\x07v\xc4\x88\xc9\xed;a\xac\x8eTn\xf5\x15\xd1\x1c"\xb8t\x0e\xeb\xbd\xb3\xf6(\xfd\x01K6\xb3\x8f\xdbQ\xa24gi`#\x9d\x18E\xe5\x13m=\x0bT\x1b\x99*\xd0\xdbs\xc0t\xbe\n\x878\xb0-I\xbb\x00\x8f]!-\xd5\xdcQ\xa15\t\xa7@b7Z\x96\x00\xdf+\xb7\xd0\x80\xb5\xa9\xaa\x0cJ\xe2\xf0\xe2\xa7\xa8W\xbc\x11\x0cN\x0e\x0b\xaeN+\xc9g\xaaD\xe5\xd2\x94\xa7s*\xd8\xf7\xa5\xd4\x83\xf2\x1ay@\x8f\x16%/}\xda\x80*LHb\t\xc8\x0b\xcf\xd4@\xa6\xc5\x03\xc1m\xc3\xe4\xe0\xb7\x9d|<\xf5G\x99\xc2\x99c,\x167\x16&f>\x11L\x96F9V`\xf3\xb3\x9d/\x9eqS\nZ$\xbfF\n\xfcc\xcb\xc2\xd9\xab`\x82\x1c\xde\xf3#e\xa8\x86\xb0\x8a\xf6\xb3`\xfb2rf\x13\\l\xe2\xac`#/\xda\x9e\xb9\xbe\xfd\xa5\x02\x8f/\xaa\x8c-ph\x7ff\xf2J\xe9C\xb2\xf9\xff\x12\xd7\xb6\xb2\x93\x83I\xfe?\xc3\x831\xcd\xd2\x0b\xd8\xa8/\xb28$\xe6\xbd\xd0\x14\xef\xde\xf4\xc9`\xf9\xe2N\x18\'|\xe9@\xfe\x9c\xdb\x0c\xbf\xec\xf4]\x03\xc1\\\xe1\xe1.\xbc\x18\x0e^\xb4F\xc2\xff\xe4\xa6%\x80/\xd0__\x90h]\xb9\x10q\xc9\x15\x17\x1f\xfd\x08\x01\xd3#W\x17\x97\x8b\x00\x03I\xe8_\xd2\\\xc3\x11\xe0\xce\xdeG\n\xc2j\'o7\xbaz\xa1\xe5$\x8c\xb0j4\xe29!w#\x8e\x7fmUj\x19zbi\xcc\xb8W\x9f\xaa\x07\x0f\xdd\xe48\xd3\x93YN\x8d\x99y\\\xf6\x1a\x8d\xd2g\xef\xe4\xc72\xb8&\xf9.\xfd\xc4\x89\xf1\x8c5]\xbeS\x8d\x07\xd8a\x87\xb4\xbfVh\x02\x15}\xcb\x825*R>\xdfr\xa8\xfa{\xa2\xb6\x0b\xc2\xf5\xf7k>\xfa\xdb\xab\xbc\x02\x9e\xa5\x1fO\xf7\xc7\xe2\x11\xdd\x94\x9b\x02E\xce\x95\xbds^\xe1\t\xbc\x15\x10\xe9M\xdb\xae\x90\xa5\xd9\xe8\x91\xca}!W$l\x1f\xd62\x08Q\x896$\x10i\xeeH\x89u"\xc0\x97\xfb\xa8\x0c\xb2\xe1\x9e\x11"\x88c\xa2\xd1\xc1\xbf\x875B>\x9b\xb3\xf0hU\xdb\x0e\x1ch\x18\xf9\xf7H\x1b\\\xfaNgs\xf5\x81\xda\x8d\x98[\x98\x1b\xce\x1f\xca\x18I5B\xd4WK\xc5\xec\x8a\xf7\xb6\xa0u\x11\xe67\xc3\x08\xa7U\x13\x00\xa1\xfd]W\xc9\x04\x7f9\xe6B\x82\xe3j\x15\x91\xdb\x01\xf7y_`eW\x18/\xc0\xd5\x88\xd4\x9d(\xafV\xe9\xf3\xf4\x14\xa9\xee\xa2m\xdan\xe8p!\xbb\xbcc\xcd\x9a\x1f\xd0\x0f\xb6\x8b\x87\xd7I\x1f\xadVb4\xd6\xbd+\xa2\xcc\t\x93*G\xa5(n\x9a\x7f\x89b/\xae\xa8rI\tjn\xc1\xeb)\xa6\xfd_\x0f\xa6\xe9\xab\xc5\xfev\xf3\xd3\xd9\x84\xc7l\xc9|\xf2\x1a\xf6\x98\x96\xeb\x1b\x1d\xd4E\xc2>\x8f\x0b\x02\xdb\xb9\xb5\xeb(\x9d`}-\\\x82a\xe0Z\x07\xe4\xd5|\xe1d\x92\xaa\xbb\x08\xb5\xd9]\xc3\xe0\xd0\xd2\x1dI:\xb9t\xe8\xf2\xfc[\x1c\xb3\xd6\xa9\x08v\xe0\xf3\r\xcf\xf4yj\x05p\xa6\xf5\xf4\xdanL\x02\xd4H\x7f\x0cV\xed/K\xa5\x8c\xfaMN^\xc8\x1aN\x05\xec\xba\xce\xa8S"\xfb\xc4\xd6\x15\xffq\xf8\x026\xa0\xc6\xba]\xcf\xfa1\x9c\xab\xdd\x99\xeb\xe55\x9d\xcc\x98u\x9f\xd3\xd4KEZ\xfb\x07Z\xab\xb9-\xe4\x15:*x\x0cg\xed\x13\xab\xf4a?"\x86\xdc\x91\xb4\x8b![G\x98\x7f\x94\xfa\x8c\xee5R|\x12\x7f\xcd\xe3_E\xc7\x07\x01$\x82 ...

# %% [markdown]
# # Visualizing/Improving decoding

# %%
seg_dic = {x:0 for x in range(15399)}
for x in simplified_droplets:
    for ind in x[0]:
        seg_dic[ind] += 1

plt.hist(seg_dic.values(), bins=28)
print(min(seg_dic.values()),max(seg_dic.values()))
# Out:
# 3 30

# %%
# nr_solves = []
# for i in range(len(simplified_droplets)):
#     output_data = {}
#     input_data = simplified_droplets[0:i]
#     newsolves = 1
#     while newsolves > 0:
#         input_data, output_data, newsolves = util.Decode(input_data, output_data)
#     nr_solves.append(len(output_data))

# %%
# x=range(len(simplified_droplets))
# plt.plot(x, nr_solves)

# %%
count=0
ind_unsolved = []
for x in input_data:
    for ind in x[0]:
        if ind not in ind_unsolved:
            ind_unsolved.append(ind)

ind_unsolved.sort()

# %%
ind_unsolved
# Out:
# []
